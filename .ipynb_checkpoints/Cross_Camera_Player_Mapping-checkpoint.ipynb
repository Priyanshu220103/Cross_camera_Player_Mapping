# %%
import torch
import cv2
import numpy as np
from torchvision import models, transforms
from scipy.spatial.distance import cosine
import pandas as pd
from collections import defaultdict

# %%
# Step 2: Use the Ultralytics API to load and use the model
from ultralytics import YOLO

# Load YOLOv8 model
model = YOLO(r'C:/Users/LENOVO-PC/Desktop/Internship/best.pt')

# %%
resnet = models.resnet18(pretrained=True)
resnet.eval()
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
# Out:
# D:\Users\LENOVO-PC\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# D:\Users\LENOVO-PC\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Initialize global ID counter and feature bank
global_id_counter = 0
global_id_bank = {}

# %%
# Initialize global ID counter and feature bank
global_id_counter = 0
global_id_bank = {}

def get_best_match(current_feat, global_id_bank, threshold=0.5):
    best_id = None
    min_dist = float("inf")
    for gid, feats in global_id_bank.items():
        for feat in feats:
            dist = cosine(current_feat, feat)
            if dist < threshold and dist < min_dist:
                min_dist = dist
                best_id = gid
    return best_id

# %%
def get_best_match(current_feat, global_id_bank, threshold=0.5):
    best_id = None
    min_dist = float("inf")
    for gid, feats in global_id_bank.items():
        for feat in feats:
            dist = cosine(current_feat, feat)
            if dist < threshold and dist < min_dist:
                min_dist = dist
                best_id = gid
    return best_id

# %%
# Inside your per-player detection loop
match_id = get_best_match(current_feat, global_id_bank)

if match_id is None:
    global_id_counter += 1
    assign_id = global_id_counter
    global_id_bank[assign_id] = [current_feat]
else:
    assign_id = match_id
    global_id_bank[assign_id].append(current_feat)

# Now use assign_id for drawing or saving

# %%
def extract_visual_features(image, bbox):
    x, y, w, h = bbox
    crop = image[y:y+h, x:x+w]
    if crop.size == 0:
        return None
    crop = cv2.resize(crop, (224, 224))
    crop = transform(crop).unsqueeze(0)
    with torch.no_grad():
        features = resnet(crop).numpy().flatten()
    return features

# %%
def detect_players(video_path):
    cap = cv2.VideoCapture(video_path)
    detections = []
    frame_idx = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        results = model(frame)
        frame_detections = []

        boxes = results[0].boxes
        if boxes is not None and boxes.xywh is not None:
            boxes_xywh = boxes.xywh.cpu().numpy()
            confidences = boxes.conf.cpu().numpy()
            classes = boxes.cls.cpu().numpy()

            for box, conf, cls in zip(boxes_xywh, confidences, classes):
                x, y, w, h = box
                print(f"Frame {frame_idx} - Class: {cls}, Conf: {conf}")
                if conf > 0.3:  # Lowered for debugging
                    features = extract_visual_features(frame, (int(x - w / 2), int(y - h / 2), int(w), int(h)))
                    if features is not None:
                        frame_detections.append({
                            'frame': frame_idx,
                            'bbox': (x, y, w, h),
                            'features': features
                        })

        print(f"Frame {frame_idx}: {len(frame_detections)} players detected")
        detections.append(frame_detections)
        frame_idx += 1

    cap.release()
    return detections

# %%
def match_players(broadcast_detections, tacticam_detections, feature_threshold=0.7):
    from collections import defaultdict
    from scipy.spatial.distance import cosine
    import numpy as np

    player_tracks = defaultdict(list)
    global_features = {}  # player_id: feature_vector
    player_id_counter = 0

    for frame_idx in range(min(len(broadcast_detections), len(tacticam_detections))):
        broadcast_players = broadcast_detections[frame_idx]
        tacticam_players = tacticam_detections[frame_idx]

        # Match broadcast players to global identities
        for b_player in broadcast_players:
            best_match_id = None
            best_similarity = -1

            for pid, global_feat in global_features.items():
                sim = 1 - cosine(b_player['features'], global_feat)
                if sim > feature_threshold and sim > best_similarity:
                    best_similarity = sim
                    best_match_id = pid

            if best_match_id is not None:
                player_id = best_match_id
                global_features[player_id] = b_player['features']
            else:
                player_id = player_id_counter
                global_features[player_id] = b_player['features']
                player_id_counter += 1

            player_tracks[player_id].append({
                'frame': frame_idx,
                'broadcast_bbox': b_player['bbox'],
                'tacticam_bbox': None
            })

        # Match tacticam players to global identities
        for t_player in tacticam_players:
            best_match_id = None
            best_similarity = -1

            for pid, global_feat in global_features.items():
                sim = 1 - cosine(t_player['features'], global_feat)
                if sim > feature_threshold and sim > best_similarity:
                    best_similarity = sim
                    best_match_id = pid

            if best_match_id is not None:
                player_id = best_match_id
                global_features[player_id] = t_player['features']
            else:
                player_id = player_id_counter
                global_features[player_id] = t_player['features']
                player_id_counter += 1

            found = False
            for i in range(len(player_tracks[player_id])):
                if player_tracks[player_id][i]['frame'] == frame_idx:
                    player_tracks[player_id][i]['tacticam_bbox'] = t_player['bbox']
                    found = True
                    break
            if not found:
                player_tracks[player_id].append({
                    'frame': frame_idx,
                    'broadcast_bbox': None,
                    'tacticam_bbox': t_player['bbox']
                })

    return player_tracks

# %%
def save_mapping(player_tracks, output_file='player_mapping.csv'):
    data = []
    for player_id, tracks in player_tracks.items():
        for track in tracks:
            data.append({
                'player_id': player_id,
                'frame': track['frame'],
                'broadcast_x': track['broadcast_bbox'][0],
                'broadcast_y': track['broadcast_bbox'][1],
                'broadcast_w': track['broadcast_bbox'][2],
                'broadcast_h': track['broadcast_bbox'][3],
                'tacticam_x': track['tacticam_bbox'][0],
                'tacticam_y': track['tacticam_bbox'][1],
                'tacticam_w': track['tacticam_bbox'][2],
                'tacticam_h': track['tacticam_bbox'][3]
            })
    df = pd.DataFrame(data)
    df.to_csv(output_file, index=False)

# %%
def main():
    broadcast_video = 'broadcast.mp4'
    tacticam_video = 'tacticam.mp4'
    print("Detecting players in broadcast video...")
    broadcast_detections = detect_players(broadcast_video)
    print("Sample broadcast detections:", broadcast_detections[:2])
    print("Detecting players in tacticam video...")
    tacticam_detections = detect_players(tacticam_video)
    print("Sample tacticam detections:", tacticam_detections[:2])
    print("Matching players across videos...")
    player_tracks = match_players(broadcast_detections, tacticam_detections)
    print("Number of tracked players:", len(player_tracks))
    print("Saving player mapping to CSV...")
    save_mapping(player_tracks)

# %%
main()
# Out:
# Detecting players in broadcast video...
#
# 0: 384x640 3 players, 386.7ms
# Speed: 4.7ms preprocess, 386.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 0 - Class: 2.0, Conf: 0.82635098695755
# Frame 0 - Class: 2.0, Conf: 0.7145757079124451
# Frame 0 - Class: 2.0, Conf: 0.5605186223983765
# Frame 0: 3 players detected
#
# 0: 384x640 2 players, 77.3ms
# Speed: 2.4ms preprocess, 77.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 1 - Class: 2.0, Conf: 0.7765336036682129
# Frame 1 - Class: 2.0, Conf: 0.341342568397522
# Frame 1: 2 players detected
#
# 0: 384x640 4 players, 73.4ms
# Speed: 2.5ms preprocess, 73.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 2 - Class: 2.0, Conf: 0.7054756283760071
# Frame 2 - Class: 2.0, Conf: 0.5709528923034668
# Frame 2 - Class: 2.0, Conf: 0.46994930505752563
# Frame 2 - Class: 2.0, Conf: 0.38390225172042847
# Frame 2: 4 players detected
#
# 0: 384x640 2 players, 72.7ms
# Speed: 2.1ms preprocess, 72.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 3 - Class: 2.0, Conf: 0.35483697056770325
# Frame 3 - Class: 2.0, Conf: 0.3338252007961273
# Frame 3: 2 players detected
#
# 0: 384x640 4 players, 73.0ms
# Speed: 2.3ms preprocess, 73.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 4 - Class: 2.0, Conf: 0.5605660676956177
# Frame 4 - Class: 2.0, Conf: 0.5349771976470947
# Frame 4 - Class: 2.0, Conf: 0.2624940574169159
# Frame 4 - Class: 2.0, Conf: 0.2602432668209076
# Frame 4: 2 players detected
#
# 0: 384x640 11 players, 1 referee, 72.9ms
# Speed: 2.4ms preprocess, 72.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 5 - Class: 2.0, Conf: 0.9278441071510315
# Frame 5 - Class: 2.0, Conf: 0.9259259104728699
# Frame 5 - Class: 2.0, Conf: 0.9126044511795044
# Frame 5 - Class: 2.0, Conf: 0.8988496661186218
# Frame 5 - Class: 2.0, Conf: 0.897085964679718
# Frame 5 - Class: 2.0, Conf: 0.8965868353843689
# Frame 5 - Class: 2.0, Conf: 0.8898844718933105
# Frame 5 - Class: 2.0, Conf: 0.8886971473693848
# Frame 5 - Class: 2.0, Conf: 0.8747303485870361
# Frame 5 - Class: 2.0, Conf: 0.8710686564445496
# Frame 5 - Class: 2.0, Conf: 0.864550769329071
# Frame 5 - Class: 3.0, Conf: 0.7642207145690918
# Frame 5: 12 players detected
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 72.7ms
# Speed: 2.5ms preprocess, 72.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 6 - Class: 2.0, Conf: 0.9321435689926147
# Frame 6 - Class: 2.0, Conf: 0.9251103401184082
# Frame 6 - Class: 2.0, Conf: 0.9221329092979431
# Frame 6 - Class: 2.0, Conf: 0.9215945601463318
# Frame 6 - Class: 2.0, Conf: 0.9196915626525879
# Frame 6 - Class: 2.0, Conf: 0.9058719277381897
# Frame 6 - Class: 2.0, Conf: 0.9020270705223083
# Frame 6 - Class: 2.0, Conf: 0.8919769525527954
# Frame 6 - Class: 2.0, Conf: 0.8801639676094055
# Frame 6 - Class: 2.0, Conf: 0.8801535367965698
# Frame 6 - Class: 2.0, Conf: 0.8687623739242554
# Frame 6 - Class: 3.0, Conf: 0.7827413082122803
# Frame 6 - Class: 2.0, Conf: 0.3645309805870056
# Frame 6 - Class: 1.0, Conf: 0.3256765902042389
# Frame 6: 14 players detected
#
# 0: 384x640 1 ball, 1 goalkeeper, 14 players, 1 referee, 71.0ms
# Speed: 2.3ms preprocess, 71.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 7 - Class: 2.0, Conf: 0.9265094995498657
# Frame 7 - Class: 2.0, Conf: 0.9180932641029358
# Frame 7 - Class: 2.0, Conf: 0.9171860814094543
# Frame 7 - Class: 2.0, Conf: 0.908626139163971
# Frame 7 - Class: 2.0, Conf: 0.9060579538345337
# Frame 7 - Class: 2.0, Conf: 0.9060085415840149
# Frame 7 - Class: 2.0, Conf: 0.9041574001312256
# Frame 7 - Class: 2.0, Conf: 0.8957814574241638
# Frame 7 - Class: 2.0, Conf: 0.8886675238609314
# Frame 7 - Class: 2.0, Conf: 0.8768052458763123
# Frame 7 - Class: 2.0, Conf: 0.8739985227584839
# Frame 7 - Class: 2.0, Conf: 0.8709349036216736
# Frame 7 - Class: 1.0, Conf: 0.8449169993400574
# Frame 7 - Class: 3.0, Conf: 0.8365143537521362
# Frame 7 - Class: 0.0, Conf: 0.733866274356842
# Frame 7 - Class: 2.0, Conf: 0.40615907311439514
# Frame 7 - Class: 2.0, Conf: 0.2916284203529358
# Frame 7: 16 players detected
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 1 referee, 71.6ms
# Speed: 2.1ms preprocess, 71.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 8 - Class: 2.0, Conf: 0.9243482947349548
# Frame 8 - Class: 2.0, Conf: 0.9185624718666077
# Frame 8 - Class: 2.0, Conf: 0.9152620434761047
# Frame 8 - Class: 2.0, Conf: 0.9147712588310242
# Frame 8 - Class: 2.0, Conf: 0.9066059589385986
# Frame 8 - Class: 2.0, Conf: 0.9052073359489441
# Frame 8 - Class: 2.0, Conf: 0.8929407596588135
# Frame 8 - Class: 2.0, Conf: 0.8900556564331055
# Frame 8 - Class: 2.0, Conf: 0.882241427898407
# Frame 8 - Class: 2.0, Conf: 0.8654310703277588
# Frame 8 - Class: 3.0, Conf: 0.8578835725784302
# Frame 8 - Class: 2.0, Conf: 0.842183530330658
# Frame 8 - Class: 0.0, Conf: 0.7905426621437073
# Frame 8 - Class: 2.0, Conf: 0.6760814785957336
# Frame 8 - Class: 1.0, Conf: 0.6734387874603271
# Frame 8 - Class: 2.0, Conf: 0.3179817199707031
# Frame 8: 16 players detected
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 1 referee, 71.9ms
# Speed: 3.0ms preprocess, 71.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 9 - Class: 2.0, Conf: 0.9214649796485901
# Frame 9 - Class: 2.0, Conf: 0.906909167766571
# Frame 9 - Class: 2.0, Conf: 0.9030452966690063
# Frame 9 - Class: 2.0, Conf: 0.899246335029602
# Frame 9 - Class: 2.0, Conf: 0.8958067893981934
# Frame 9 - Class: 2.0, Conf: 0.8879805207252502
# Frame 9 - Class: 2.0, Conf: 0.8872869610786438
# Frame 9 - Class: 2.0, Conf: 0.8853731751441956
# Frame 9 - Class: 2.0, Conf: 0.8779075741767883
# Frame 9 - Class: 2.0, Conf: 0.8660464286804199
# Frame 9 - Class: 2.0, Conf: 0.8593041896820068
# Frame 9 - Class: 3.0, Conf: 0.8367041945457458
# Frame 9 - Class: 1.0, Conf: 0.6332871317863464
# Frame 9 - Class: 2.0, Conf: 0.5339917540550232
# Frame 9 - Class: 2.0, Conf: 0.4112309515476227
# Frame 9 - Class: 0.0, Conf: 0.26020941138267517
# Frame 9: 15 players detected
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 71.3ms
# Speed: 2.3ms preprocess, 71.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 10 - Class: 2.0, Conf: 0.9193328619003296
# Frame 10 - Class: 2.0, Conf: 0.9118944406509399
# Frame 10 - Class: 2.0, Conf: 0.9116483330726624
# Frame 10 - Class: 2.0, Conf: 0.9004698395729065
# Frame 10 - Class: 2.0, Conf: 0.9000870585441589
# Frame 10 - Class: 2.0, Conf: 0.8985376954078674
# Frame 10 - Class: 2.0, Conf: 0.8944726586341858
# Frame 10 - Class: 2.0, Conf: 0.8819857835769653
# Frame 10 - Class: 2.0, Conf: 0.8763934969902039
# Frame 10 - Class: 2.0, Conf: 0.863117516040802
# Frame 10 - Class: 2.0, Conf: 0.8630400896072388
# Frame 10 - Class: 3.0, Conf: 0.8442384004592896
# Frame 10 - Class: 1.0, Conf: 0.8061643242835999
# Frame 10 - Class: 0.0, Conf: 0.6230417490005493
# Frame 10 - Class: 2.0, Conf: 0.2789531350135803
# Frame 10: 14 players detected
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 1 referee, 83.9ms
# Speed: 2.1ms preprocess, 83.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 11 - Class: 2.0, Conf: 0.9268084168434143
# Frame 11 - Class: 2.0, Conf: 0.9257212281227112
# Frame 11 - Class: 2.0, Conf: 0.9157813787460327
# Frame 11 - Class: 2.0, Conf: 0.9149950742721558
# Frame 11 - Class: 2.0, Conf: 0.9046724438667297
# Frame 11 - Class: 2.0, Conf: 0.9024191498756409
# Frame 11 - Class: 2.0, Conf: 0.8994532823562622
# Frame 11 - Class: 2.0, Conf: 0.8947882056236267
# Frame 11 - Class: 2.0, Conf: 0.8939254283905029
# Frame 11 - Class: 2.0, Conf: 0.8854151964187622
# Frame 11 - Class: 1.0, Conf: 0.8681761622428894
# Frame 11 - Class: 2.0, Conf: 0.8244459629058838
# Frame 11 - Class: 3.0, Conf: 0.8128734230995178
# Frame 11 - Class: 0.0, Conf: 0.4957433342933655
# Frame 11 - Class: 2.0, Conf: 0.47013744711875916
# Frame 11 - Class: 2.0, Conf: 0.3448631763458252
# Frame 11: 16 players detected
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 97.0ms
# Speed: 2.2ms preprocess, 97.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 12 - Class: 2.0, Conf: 0.9292099475860596
# Frame 12 - Class: 2.0, Conf: 0.9163652062416077
# Frame 12 - Class: 2.0, Conf: 0.9101170301437378
# Frame 12 - Class: 2.0, Conf: 0.9086831212043762
# Frame 12 - Class: 2.0, Conf: 0.9081701636314392
# Frame 12 - Class: 2.0, Conf: 0.9051020741462708
# Frame 12 - Class: 2.0, Conf: 0.8991541266441345
# Frame 12 - Class: 2.0, Conf: 0.8965305685997009
# Frame 12 - Class: 2.0, Conf: 0.8921339511871338
# Frame 12 - Class: 2.0, Conf: 0.8898547291755676
# Frame 12 - Class: 2.0, Conf: 0.8818618655204773
# Frame 12 - Class: 3.0, Conf: 0.8551615476608276
# Frame 12 - Class: 1.0, Conf: 0.7799401879310608
# Frame 12: 13 players detected
#
# 0: 384x640 13 players, 2 referees, 76.6ms
# Speed: 2.6ms preprocess, 76.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 13 - Class: 2.0, Conf: 0.9302376508712769
# Frame 13 - Class: 2.0, Conf: 0.9195692539215088
# Frame 13 - Class: 2.0, Conf: 0.9119757413864136
# Frame 13 - Class: 2.0, Conf: 0.9057155847549438
# Frame 13 - Class: 2.0, Conf: 0.8945668935775757
# Frame 13 - Class: 2.0, Conf: 0.8940701484680176
# Frame 13 - Class: 2.0, Conf: 0.8922494649887085
# Frame 13 - Class: 2.0, Conf: 0.8876499533653259
# Frame 13 - Class: 2.0, Conf: 0.8820717334747314
# Frame 13 - Class: 2.0, Conf: 0.8797522187232971
# Frame 13 - Class: 3.0, Conf: 0.8408666253089905
# Frame 13 - Class: 2.0, Conf: 0.8216114640235901
# Frame 13 - Class: 3.0, Conf: 0.8206601142883301
# Frame 13 - Class: 2.0, Conf: 0.7855566740036011
# Frame 13 - Class: 2.0, Conf: 0.5046147108078003
# Frame 13: 15 players detected
#
# 0: 384x640 12 players, 3 referees, 76.5ms
# Speed: 1.8ms preprocess, 76.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 14 - Class: 2.0, Conf: 0.9295167326927185
# Frame 14 - Class: 2.0, Conf: 0.9148639440536499
# Frame 14 - Class: 2.0, Conf: 0.9083864092826843
# Frame 14 - Class: 2.0, Conf: 0.9050800800323486
# Frame 14 - Class: 2.0, Conf: 0.8996827602386475
# Frame 14 - Class: 2.0, Conf: 0.8976555466651917
# Frame 14 - Class: 2.0, Conf: 0.8955047726631165
# Frame 14 - Class: 2.0, Conf: 0.8941328525543213
# Frame 14 - Class: 2.0, Conf: 0.8881990909576416
# Frame 14 - Class: 2.0, Conf: 0.8833461999893188
# Frame 14 - Class: 2.0, Conf: 0.8618968725204468
# Frame 14 - Class: 2.0, Conf: 0.8479806780815125
# Frame 14 - Class: 3.0, Conf: 0.846637487411499
# Frame 14 - Class: 3.0, Conf: 0.8207527995109558
# Frame 14 - Class: 3.0, Conf: 0.5853639245033264
# Frame 14: 15 players detected
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 76.6ms
# Speed: 2.1ms preprocess, 76.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 15 - Class: 2.0, Conf: 0.9345433712005615
# Frame 15 - Class: 2.0, Conf: 0.9142583012580872
# Frame 15 - Class: 2.0, Conf: 0.9120941162109375
# Frame 15 - Class: 2.0, Conf: 0.9060649871826172
# Frame 15 - Class: 2.0, Conf: 0.9040574431419373
# Frame 15 - Class: 2.0, Conf: 0.8985527157783508
# Frame 15 - Class: 2.0, Conf: 0.894967257976532
# Frame 15 - Class: 2.0, Conf: 0.8895848393440247
# Frame 15 - Class: 2.0, Conf: 0.8855148553848267
# Frame 15 - Class: 2.0, Conf: 0.8820016980171204
# Frame 15 - Class: 1.0, Conf: 0.8617098927497864
# Frame 15 - Class: 3.0, Conf: 0.849145233631134
# Frame 15 - Class: 2.0, Conf: 0.8472066521644592
# Frame 15 - Class: 3.0, Conf: 0.7985934019088745
# Frame 15: 14 players detected
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 76.5ms
# Speed: 2.3ms preprocess, 76.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 16 - Class: 2.0, Conf: 0.9337527751922607
# Frame 16 - Class: 2.0, Conf: 0.9125320911407471
# Frame 16 - Class: 2.0, Conf: 0.9053403735160828
# Frame 16 - Class: 2.0, Conf: 0.9028856754302979
# Frame 16 - Class: 2.0, Conf: 0.9025894999504089
# Frame 16 - Class: 2.0, Conf: 0.8978231549263
# Frame 16 - Class: 2.0, Conf: 0.8934483528137207
# Frame 16 - Class: 2.0, Conf: 0.8851001858711243
# Frame 16 - Class: 2.0, Conf: 0.876730740070343
# Frame 16 - Class: 2.0, Conf: 0.8650022149085999
# Frame 16 - Class: 3.0, Conf: 0.8632651567459106
# Frame 16 - Class: 2.0, Conf: 0.8614659309387207
# Frame 16 - Class: 1.0, Conf: 0.8527302742004395
# Frame 16 - Class: 3.0, Conf: 0.8302366137504578
# Frame 16: 14 players detected
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 2 referees, 84.1ms
# Speed: 2.3ms preprocess, 84.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 17 - Class: 2.0, Conf: 0.9387238621711731
# Frame 17 - Class: 2.0, Conf: 0.9141626358032227
# Frame 17 - Class: 2.0, Conf: 0.9140650629997253
# Frame 17 - Class: 2.0, Conf: 0.9053109884262085
# Frame 17 - Class: 2.0, Conf: 0.9048375487327576
# Frame 17 - Class: 2.0, Conf: 0.9018835425376892
# Frame 17 - Class: 2.0, Conf: 0.8883169293403625
# Frame 17 - Class: 2.0, Conf: 0.8816219568252563
# Frame 17 - Class: 2.0, Conf: 0.8750506043434143
# Frame 17 - Class: 2.0, Conf: 0.8649855852127075
# Frame 17 - Class: 2.0, Conf: 0.8487310409545898
# Frame 17 - Class: 1.0, Conf: 0.8084604740142822
# Frame 17 - Class: 3.0, Conf: 0.7990331649780273
# Frame 17 - Class: 2.0, Conf: 0.7803239226341248
# Frame 17 - Class: 3.0, Conf: 0.779715359210968
# Frame 17 - Class: 0.0, Conf: 0.6721466779708862
# Frame 17: 16 players detected
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 2 referees, 97.2ms
# Speed: 3.0ms preprocess, 97.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 18 - Class: 2.0, Conf: 0.931591808795929
# Frame 18 - Class: 2.0, Conf: 0.9164719581604004
# Frame 18 - Class: 2.0, Conf: 0.9117746949195862
# Frame 18 - Class: 2.0, Conf: 0.9044830203056335
# Frame 18 - Class: 2.0, Conf: 0.9001122713088989
# Frame 18 - Class: 2.0, Conf: 0.9001078009605408
# Frame 18 - Class: 2.0, Conf: 0.9000080823898315
# Frame 18 - Class: 2.0, Conf: 0.898621678352356
# Frame 18 - Class: 2.0, Conf: 0.8820083737373352
# Frame 18 - Class: 2.0, Conf: 0.8765053749084473
# Frame 18 - Class: 2.0, Conf: 0.8514289855957031
# Frame 18 - Class: 1.0, Conf: 0.8210200071334839
# Frame 18 - Class: 3.0, Conf: 0.7164455652236938
# Frame 18 - Class: 3.0, Conf: 0.34883877635002136
# Frame 18 - Class: 0.0, Conf: 0.32025033235549927
# Frame 18: 15 players detected
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 78.8ms
# Speed: 2.3ms preprocess, 78.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 19 - Class: 2.0, Conf: 0.937903106212616
# Frame 19 - Class: 2.0, Conf: 0.925347089767456
# Frame 19 - Class: 2.0, Conf: 0.9167842268943787
# Frame 19 - Class: 2.0, Conf: 0.9093117117881775
# Frame 19 - Class: 2.0, Conf: 0.9044939279556274
# Frame 19 - Class: 2.0, Conf: 0.9024989008903503
# Frame 19 - Class: 2.0, Conf: 0.9022355675697327
# Frame 19 - Class: 2.0, Conf: 0.8991407155990601
# Frame 19 - Class: 2.0, Conf: 0.8986572623252869
# Frame 19 - Class: 3.0, Conf: 0.8727700710296631
# Frame 19 - Class: 1.0, Conf: 0.8476186394691467
# Frame 19 - Class: 2.0, Conf: 0.8429860472679138
# Frame 19 - Class: 3.0, Conf: 0.8269799947738647
# Frame 19 - Class: 2.0, Conf: 0.8096357583999634
# Frame 19: 14 players detected
#
# 0: 384x640 1 goalkeeper, 12 players, 2 referees, 78.9ms
# Speed: 2.2ms preprocess, 78.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 20 - Class: 2.0, Conf: 0.9300704598426819
# Frame 20 - Class: 2.0, Conf: 0.9204027652740479
# Frame 20 - Class: 2.0, Conf: 0.9202541708946228
# Frame 20 - Class: 2.0, Conf: 0.9193277955055237
# Frame 20 - Class: 2.0, Conf: 0.9090508818626404
# Frame 20 - Class: 2.0, Conf: 0.9080042243003845
# Frame 20 - Class: 2.0, Conf: 0.9053729176521301
# Frame 20 - Class: 2.0, Conf: 0.9013528823852539
# Frame 20 - Class: 2.0, Conf: 0.8629839420318604
# Frame 20 - Class: 3.0, Conf: 0.8459218144416809
# Frame 20 - Class: 2.0, Conf: 0.8446149826049805
# Frame 20 - Class: 2.0, Conf: 0.8075894713401794
# Frame 20 - Class: 3.0, Conf: 0.8014624714851379
# Frame 20 - Class: 1.0, Conf: 0.47770974040031433
# Frame 20 - Class: 2.0, Conf: 0.3376297354698181
# Frame 20: 15 players detected
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 78.9ms
# Speed: 2.4ms preprocess, 78.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 21 - Class: 2.0, Conf: 0.9327743053436279
# Frame 21 - Class: 2.0, Conf: 0.9259960055351257
# Frame 21 - Class: 2.0, Conf: 0.9249109029769897
# Frame 21 - Class: 2.0, Conf: 0.9184802770614624
# Frame 21 - Class: 2.0, Conf: 0.9072554111480713
# Frame 21 - Class: 2.0, Conf: 0.8938129544258118
# Frame 21 - Class: 2.0, Conf: 0.8930171132087708
# Frame 21 - Class: 2.0, Conf: 0.8904113173484802
# Frame 21 - Class: 2.0, Conf: 0.8862651586532593
# Frame 21 - Class: 2.0, Conf: 0.8720630407333374
# Frame 21 - Class: 2.0, Conf: 0.8577529788017273
# Frame 21 - Class: 3.0, Conf: 0.8529482483863831
# Frame 21 - Class: 1.0, Conf: 0.8057854771614075
# Frame 21 - Class: 3.0, Conf: 0.6920841336250305
# Frame 21: 14 players detected
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1 referee, 77.6ms
# Speed: 1.9ms preprocess, 77.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 22 - Class: 2.0, Conf: 0.9230058789253235
# Frame 22 - Class: 2.0, Conf: 0.9219467043876648
# Frame 22 - Class: 2.0, Conf: 0.9139060378074646
# Frame 22 - Class: 2.0, Conf: 0.9134410619735718
# Frame 22 - Class: 2.0, Conf: 0.9108694791793823
# Frame 22 - Class: 2.0, Conf: 0.9101645350456238
# Frame 22 - Class: 2.0, Conf: 0.9043207764625549
# Frame 22 - Class: 2.0, Conf: 0.8896270990371704
# Frame 22 - Class: 2.0, Conf: 0.8757504820823669
# Frame 22 - Class: 2.0, Conf: 0.8618674874305725
# Frame 22 - Class: 2.0, Conf: 0.8344494104385376
# Frame 22 - Class: 3.0, Conf: 0.8235079646110535
# Frame 22 - Class: 1.0, Conf: 0.7946180701255798
# Frame 22 - Class: 0.0, Conf: 0.5144808292388916
# Frame 22: 14 players detected
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 76.6ms
# Speed: 2.5ms preprocess, 76.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 23 - Class: 2.0, Conf: 0.9266896843910217
# Frame 23 - Class: 2.0, Conf: 0.9221664667129517
# Frame 23 - Class: 2.0, Conf: 0.9215896129608154
# Frame 23 - Class: 2.0, Conf: 0.9165772199630737
# Frame 23 - Class: 2.0, Conf: 0.910615086555481
# Frame 23 - Class: 2.0, Conf: 0.9095995426177979
# Frame 23 - Class: 2.0, Conf: 0.8965107202529907
# Frame 23 - Class: 2.0, Conf: 0.8944254517555237
# Frame 23 - Class: 2.0, Conf: 0.8846852779388428
# Frame 23 - Class: 2.0, Conf: 0.8771427273750305
# Frame 23 - Class: 2.0, Conf: 0.8448039293289185
# Frame 23 - Class: 3.0, Conf: 0.805059552192688
# Frame 23 - Class: 1.0, Conf: 0.7971544861793518
# Frame 23 - Class: 0.0, Conf: 0.5905472636222839
# Frame 23 - Class: 2.0, Conf: 0.30414095520973206
# Frame 23: 15 players detected
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 75.4ms
# Speed: 1.9ms preprocess, 75.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 24 - Class: 2.0, Conf: 0.9249430298805237
# Frame 24 - Class: 2.0, Conf: 0.918765664100647
# Frame 24 - Class: 2.0, Conf: 0.915025532245636
# Frame 24 - Class: 2.0, Conf: 0.910674512386322
# Frame 24 - Class: 2.0, Conf: 0.9101915955543518
# Frame 24 - Class: 2.0, Conf: 0.892805814743042
# Frame 24 - Class: 2.0, Conf: 0.8788197040557861
# Frame 24 - Class: 2.0, Conf: 0.8787725567817688
# Frame 24 - Class: 2.0, Conf: 0.8702945113182068
# Frame 24 - Class: 2.0, Conf: 0.8544982671737671
# Frame 24 - Class: 2.0, Conf: 0.8180071711540222
# Frame 24 - Class: 3.0, Conf: 0.7697593569755554
# Frame 24 - Class: 1.0, Conf: 0.7444205284118652
# Frame 24 - Class: 0.0, Conf: 0.7167327404022217
# Frame 24 - Class: 2.0, Conf: 0.6870914101600647
# Frame 24: 15 players detected
#
# 0: 384x640 1 ball, 14 players, 2 referees, 75.5ms
# Speed: 2.4ms preprocess, 75.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 25 - Class: 2.0, Conf: 0.9226413369178772
# Frame 25 - Class: 2.0, Conf: 0.9167842268943787
# Frame 25 - Class: 2.0, Conf: 0.9098862409591675
# Frame 25 - Class: 2.0, Conf: 0.8989796042442322
# Frame 25 - Class: 2.0, Conf: 0.8872045874595642
# Frame 25 - Class: 2.0, Conf: 0.8865845799446106
# Frame 25 - Class: 2.0, Conf: 0.8849914073944092
# Frame 25 - Class: 2.0, Conf: 0.8752893805503845
# Frame 25 - Class: 2.0, Conf: 0.8533146977424622
# Frame 25 - Class: 2.0, Conf: 0.8354491591453552
# Frame 25 - Class: 2.0, Conf: 0.8256291151046753
# Frame 25 - Class: 3.0, Conf: 0.8185116052627563
# Frame 25 - Class: 2.0, Conf: 0.8158559203147888
# Frame 25 - Class: 3.0, Conf: 0.7498734593391418
# Frame 25 - Class: 0.0, Conf: 0.6911786794662476
# Frame 25 - Class: 2.0, Conf: 0.6336480379104614
# Frame 25 - Class: 2.0, Conf: 0.5673273801803589
# Frame 25: 17 players detected
#
# 0: 384x640 1 ball, 12 players, 2 referees, 75.4ms
# Speed: 2.3ms preprocess, 75.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 26 - Class: 2.0, Conf: 0.9225965738296509
# Frame 26 - Class: 2.0, Conf: 0.9092012643814087
# Frame 26 - Class: 2.0, Conf: 0.9059480428695679
# Frame 26 - Class: 2.0, Conf: 0.9040973782539368
# Frame 26 - Class: 2.0, Conf: 0.8972640037536621
# Frame 26 - Class: 2.0, Conf: 0.895452618598938
# Frame 26 - Class: 2.0, Conf: 0.8949218392372131
# Frame 26 - Class: 2.0, Conf: 0.8866861462593079
# Frame 26 - Class: 2.0, Conf: 0.8844983577728271
# Frame 26 - Class: 2.0, Conf: 0.8801072835922241
# Frame 26 - Class: 2.0, Conf: 0.8147612810134888
# Frame 26 - Class: 3.0, Conf: 0.7608140110969543
# Frame 26 - Class: 2.0, Conf: 0.6983923316001892
# Frame 26 - Class: 0.0, Conf: 0.6874339580535889
# Frame 26 - Class: 3.0, Conf: 0.6675704121589661
# Frame 26: 15 players detected
#
# 0: 384x640 1 ball, 12 players, 2 referees, 97.5ms
# Speed: 2.2ms preprocess, 97.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 27 - Class: 2.0, Conf: 0.9298980832099915
# Frame 27 - Class: 2.0, Conf: 0.9223940968513489
# Frame 27 - Class: 2.0, Conf: 0.9132469296455383
# Frame 27 - Class: 2.0, Conf: 0.9075583219528198
# Frame 27 - Class: 2.0, Conf: 0.9064955115318298
# Frame 27 - Class: 2.0, Conf: 0.894885241985321
# Frame 27 - Class: 2.0, Conf: 0.8855013847351074
# Frame 27 - Class: 2.0, Conf: 0.8852295875549316
# Frame 27 - Class: 2.0, Conf: 0.8805943727493286
# Frame 27 - Class: 2.0, Conf: 0.8798732757568359
# Frame 27 - Class: 3.0, Conf: 0.8036741614341736
# Frame 27 - Class: 2.0, Conf: 0.7711671590805054
# Frame 27 - Class: 2.0, Conf: 0.7413665652275085
# Frame 27 - Class: 3.0, Conf: 0.7085022330284119
# Frame 27 - Class: 0.0, Conf: 0.7058806419372559
# Frame 27: 15 players detected
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 2 referees, 79.4ms
# Speed: 2.4ms preprocess, 79.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 28 - Class: 2.0, Conf: 0.9432374835014343
# Frame 28 - Class: 2.0, Conf: 0.9105855226516724
# Frame 28 - Class: 2.0, Conf: 0.9091913104057312
# Frame 28 - Class: 2.0, Conf: 0.9070159792900085
# Frame 28 - Class: 2.0, Conf: 0.9051697254180908
# Frame 28 - Class: 2.0, Conf: 0.8990306854248047
# Frame 28 - Class: 2.0, Conf: 0.8932995200157166
# Frame 28 - Class: 2.0, Conf: 0.8889725208282471
# Frame 28 - Class: 2.0, Conf: 0.88722825050354
# Frame 28 - Class: 2.0, Conf: 0.8822727799415588
# Frame 28 - Class: 2.0, Conf: 0.8116373419761658
# Frame 28 - Class: 3.0, Conf: 0.8006893992424011
# Frame 28 - Class: 3.0, Conf: 0.7718650102615356
# Frame 28 - Class: 0.0, Conf: 0.6515549421310425
# Frame 28 - Class: 1.0, Conf: 0.391874223947525
# Frame 28 - Class: 2.0, Conf: 0.26760438084602356
# Frame 28: 15 players detected
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 2 referees, 77.7ms
# Speed: 2.5ms preprocess, 77.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 29 - Class: 2.0, Conf: 0.9404718279838562
# Frame 29 - Class: 2.0, Conf: 0.9203301668167114
# Frame 29 - Class: 2.0, Conf: 0.9166930913925171
# Frame 29 - Class: 2.0, Conf: 0.9128005504608154
# Frame 29 - Class: 2.0, Conf: 0.9072496294975281
# Frame 29 - Class: 2.0, Conf: 0.9050390720367432
# Frame 29 - Class: 2.0, Conf: 0.9044914245605469
# Frame 29 - Class: 2.0, Conf: 0.9019431471824646
# Frame 29 - Class: 2.0, Conf: 0.8783466815948486
# Frame 29 - Class: 2.0, Conf: 0.8732368350028992
# Frame 29 - Class: 2.0, Conf: 0.7898129224777222
# Frame 29 - Class: 1.0, Conf: 0.7651038765907288
# Frame 29 - Class: 2.0, Conf: 0.7641280889511108
# Frame 29 - Class: 3.0, Conf: 0.7219904065132141
# Frame 29 - Class: 3.0, Conf: 0.4853028953075409
# Frame 29 - Class: 0.0, Conf: 0.35006284713745117
# Frame 29: 16 players detected
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1 referee, 77.7ms
# Speed: 2.0ms preprocess, 77.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 30 - Class: 2.0, Conf: 0.9280440807342529
# Frame 30 - Class: 2.0, Conf: 0.9181718230247498
# Frame 30 - Class: 2.0, Conf: 0.9180276393890381
# Frame 30 - Class: 2.0, Conf: 0.9169665575027466
# Frame 30 - Class: 2.0, Conf: 0.9134572744369507
# Frame 30 - Class: 2.0, Conf: 0.9093363881111145
# Frame 30 - Class: 2.0, Conf: 0.9019822478294373
# Frame 30 - Class: 2.0, Conf: 0.9008893966674805
# Frame 30 - Class: 2.0, Conf: 0.8842612504959106
# Frame 30 - Class: 2.0, Conf: 0.8831552863121033
# Frame 30 - Class: 1.0, Conf: 0.7929009795188904
# Frame 30 - Class: 3.0, Conf: 0.7492010593414307
# Frame 30 - Class: 2.0, Conf: 0.584533154964447
# Frame 30 - Class: 0.0, Conf: 0.2970280647277832
# Frame 30: 13 players detected
#
# 0: 384x640 1 goalkeeper, 11 players, 3 referees, 77.6ms
# Speed: 2.2ms preprocess, 77.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 31 - Class: 2.0, Conf: 0.9262075424194336
# Frame 31 - Class: 2.0, Conf: 0.9154916405677795
# Frame 31 - Class: 2.0, Conf: 0.9149911999702454
# Frame 31 - Class: 2.0, Conf: 0.9146029353141785
# Frame 31 - Class: 2.0, Conf: 0.9125995635986328
# Frame 31 - Class: 2.0, Conf: 0.9064397811889648
# Frame 31 - Class: 2.0, Conf: 0.8962318301200867
# Frame 31 - Class: 2.0, Conf: 0.8936666250228882
# Frame 31 - Class: 2.0, Conf: 0.8919506669044495
# Frame 31 - Class: 2.0, Conf: 0.8483161926269531
# Frame 31 - Class: 1.0, Conf: 0.8458088040351868
# Frame 31 - Class: 2.0, Conf: 0.8280438780784607
# Frame 31 - Class: 3.0, Conf: 0.6187950372695923
# Frame 31 - Class: 3.0, Conf: 0.5846755504608154
# Frame 31 - Class: 3.0, Conf: 0.35910576581954956
# Frame 31: 15 players detected
#
# 0: 384x640 1 goalkeeper, 13 players, 1 referee, 78.3ms
# Speed: 2.4ms preprocess, 78.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 32 - Class: 2.0, Conf: 0.922301709651947
# Frame 32 - Class: 2.0, Conf: 0.9220975041389465
# Frame 32 - Class: 2.0, Conf: 0.9204140901565552
# Frame 32 - Class: 2.0, Conf: 0.9146255254745483
# Frame 32 - Class: 2.0, Conf: 0.9102414846420288
# Frame 32 - Class: 2.0, Conf: 0.9002993702888489
# Frame 32 - Class: 2.0, Conf: 0.8882295489311218
# Frame 32 - Class: 1.0, Conf: 0.884372353553772
# Frame 32 - Class: 2.0, Conf: 0.8754072785377502
# Frame 32 - Class: 2.0, Conf: 0.8635549545288086
# Frame 32 - Class: 2.0, Conf: 0.8424200415611267
# Frame 32 - Class: 3.0, Conf: 0.8191616535186768
# Frame 32 - Class: 2.0, Conf: 0.8087419271469116
# Frame 32 - Class: 2.0, Conf: 0.3797956705093384
# Frame 32 - Class: 2.0, Conf: 0.30975237488746643
# Frame 32: 15 players detected
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1 referee, 97.3ms
# Speed: 2.7ms preprocess, 97.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 33 - Class: 2.0, Conf: 0.9213001132011414
# Frame 33 - Class: 2.0, Conf: 0.9197580218315125
# Frame 33 - Class: 2.0, Conf: 0.9194294810295105
# Frame 33 - Class: 2.0, Conf: 0.9111147522926331
# Frame 33 - Class: 2.0, Conf: 0.9071568250656128
# Frame 33 - Class: 2.0, Conf: 0.9070146083831787
# Frame 33 - Class: 2.0, Conf: 0.9059247970581055
# Frame 33 - Class: 2.0, Conf: 0.8888892531394958
# Frame 33 - Class: 1.0, Conf: 0.8414028286933899
# Frame 33 - Class: 2.0, Conf: 0.8156151175498962
# Frame 33 - Class: 3.0, Conf: 0.801335334777832
# Frame 33 - Class: 2.0, Conf: 0.7801110148429871
# Frame 33 - Class: 0.0, Conf: 0.6589514017105103
# Frame 33 - Class: 2.0, Conf: 0.6253770589828491
# Frame 33: 14 players detected
#
# 0: 384x640 1 goalkeeper, 13 players, 1 referee, 80.8ms
# Speed: 2.1ms preprocess, 80.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 34 - Class: 2.0, Conf: 0.924196183681488
# Frame 34 - Class: 2.0, Conf: 0.9234827756881714
# Frame 34 - Class: 2.0, Conf: 0.9085881114006042
# Frame 34 - Class: 2.0, Conf: 0.900952160358429
# Frame 34 - Class: 2.0, Conf: 0.8995237946510315
# Frame 34 - Class: 2.0, Conf: 0.8868088722229004
# Frame 34 - Class: 2.0, Conf: 0.8845263123512268
# Frame 34 - Class: 2.0, Conf: 0.8732047080993652
# Frame 34 - Class: 1.0, Conf: 0.8370437622070312
# Frame 34 - Class: 2.0, Conf: 0.8182932734489441
# Frame 34 - Class: 2.0, Conf: 0.7156215906143188
# Frame 34 - Class: 3.0, Conf: 0.6729551553726196
# Frame 34 - Class: 2.0, Conf: 0.6268141865730286
# Frame 34 - Class: 2.0, Conf: 0.5540475845336914
# Frame 34 - Class: 2.0, Conf: 0.5007120370864868
# Frame 34: 15 players detected
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 76.6ms
# Speed: 1.7ms preprocess, 76.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 35 - Class: 2.0, Conf: 0.925139307975769
# Frame 35 - Class: 2.0, Conf: 0.9241901636123657
# Frame 35 - Class: 2.0, Conf: 0.9111155271530151
# Frame 35 - Class: 2.0, Conf: 0.9092947840690613
# Frame 35 - Class: 2.0, Conf: 0.9071009159088135
# Frame 35 - Class: 2.0, Conf: 0.8999090194702148
# Frame 35 - Class: 2.0, Conf: 0.8982113003730774
# Frame 35 - Class: 2.0, Conf: 0.8885028958320618
# Frame 35 - Class: 2.0, Conf: 0.8571891188621521
# Frame 35 - Class: 3.0, Conf: 0.7408753037452698
# Frame 35 - Class: 2.0, Conf: 0.7323666214942932
# Frame 35 - Class: 1.0, Conf: 0.5739043951034546
# Frame 35 - Class: 2.0, Conf: 0.44753339886665344
# Frame 35 - Class: 2.0, Conf: 0.39382636547088623
# Frame 35: 14 players detected
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 76.6ms
# Speed: 2.1ms preprocess, 76.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 36 - Class: 2.0, Conf: 0.9227195978164673
# Frame 36 - Class: 2.0, Conf: 0.9199614524841309
# Frame 36 - Class: 2.0, Conf: 0.911573052406311
# Frame 36 - Class: 2.0, Conf: 0.9112730026245117
# Frame 36 - Class: 2.0, Conf: 0.9060819149017334
# Frame 36 - Class: 2.0, Conf: 0.9056336283683777
# Frame 36 - Class: 2.0, Conf: 0.8939156532287598
# Frame 36 - Class: 2.0, Conf: 0.8866936564445496
# Frame 36 - Class: 2.0, Conf: 0.793907880783081
# Frame 36 - Class: 3.0, Conf: 0.7777548432350159
# Frame 36 - Class: 2.0, Conf: 0.7526540756225586
# Frame 36 - Class: 2.0, Conf: 0.7349514961242676
# Frame 36 - Class: 1.0, Conf: 0.4780448079109192
# Frame 36 - Class: 2.0, Conf: 0.2987569570541382
# Frame 36: 13 players detected
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 76.6ms
# Speed: 2.5ms preprocess, 76.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 37 - Class: 2.0, Conf: 0.9363104104995728
# Frame 37 - Class: 2.0, Conf: 0.9176152348518372
# Frame 37 - Class: 2.0, Conf: 0.916771411895752
# Frame 37 - Class: 2.0, Conf: 0.9120373129844666
# Frame 37 - Class: 2.0, Conf: 0.904062032699585
# Frame 37 - Class: 2.0, Conf: 0.9001644253730774
# Frame 37 - Class: 2.0, Conf: 0.8967611789703369
# Frame 37 - Class: 2.0, Conf: 0.8848261833190918
# Frame 37 - Class: 3.0, Conf: 0.8316978812217712
# Frame 37 - Class: 2.0, Conf: 0.722603440284729
# Frame 37 - Class: 2.0, Conf: 0.6554717421531677
# Frame 37 - Class: 2.0, Conf: 0.5303146839141846
# Frame 37 - Class: 2.0, Conf: 0.5010197162628174
# Frame 37 - Class: 1.0, Conf: 0.4324289560317993
# Frame 37 - Class: 0.0, Conf: 0.348579078912735
# Frame 37: 15 players detected
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 76.6ms
# Speed: 2.4ms preprocess, 76.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 38 - Class: 2.0, Conf: 0.9331327676773071
# Frame 38 - Class: 2.0, Conf: 0.92952561378479
# Frame 38 - Class: 2.0, Conf: 0.9152051210403442
# Frame 38 - Class: 2.0, Conf: 0.9126104712486267
# Frame 38 - Class: 2.0, Conf: 0.9097180962562561
# Frame 38 - Class: 2.0, Conf: 0.9042443633079529
# Frame 38 - Class: 2.0, Conf: 0.890333354473114
# Frame 38 - Class: 2.0, Conf: 0.8788053393363953
# Frame 38 - Class: 3.0, Conf: 0.8353714346885681
# Frame 38 - Class: 2.0, Conf: 0.7910981178283691
# Frame 38 - Class: 2.0, Conf: 0.6782074570655823
# Frame 38 - Class: 2.0, Conf: 0.6286932826042175
# Frame 38 - Class: 1.0, Conf: 0.37628060579299927
# Frame 38: 13 players detected
#
# 0: 384x640 11 players, 1 referee, 76.1ms
# Speed: 2.1ms preprocess, 76.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 39 - Class: 2.0, Conf: 0.9276091456413269
# Frame 39 - Class: 2.0, Conf: 0.9164639711380005
# Frame 39 - Class: 2.0, Conf: 0.9161685705184937
# Frame 39 - Class: 2.0, Conf: 0.9106435775756836
# Frame 39 - Class: 2.0, Conf: 0.9101763963699341
# Frame 39 - Class: 2.0, Conf: 0.8919716477394104
# Frame 39 - Class: 2.0, Conf: 0.8684679269790649
# Frame 39 - Class: 2.0, Conf: 0.8624303936958313
# Frame 39 - Class: 3.0, Conf: 0.8414384722709656
# Frame 39 - Class: 2.0, Conf: 0.8071657419204712
# Frame 39 - Class: 2.0, Conf: 0.8019184470176697
# Frame 39 - Class: 2.0, Conf: 0.710170567035675
# Frame 39: 12 players detected
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 75.9ms
# Speed: 2.1ms preprocess, 75.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 40 - Class: 2.0, Conf: 0.9252535700798035
# Frame 40 - Class: 2.0, Conf: 0.9204829931259155
# Frame 40 - Class: 2.0, Conf: 0.9193176627159119
# Frame 40 - Class: 2.0, Conf: 0.9185885787010193
# Frame 40 - Class: 2.0, Conf: 0.9177666306495667
# Frame 40 - Class: 2.0, Conf: 0.9132717847824097
# Frame 40 - Class: 2.0, Conf: 0.9092305302619934
# Frame 40 - Class: 1.0, Conf: 0.8876782059669495
# Frame 40 - Class: 2.0, Conf: 0.874784529209137
# Frame 40 - Class: 2.0, Conf: 0.8523949384689331
# Frame 40 - Class: 3.0, Conf: 0.7533325552940369
# Frame 40 - Class: 2.0, Conf: 0.7060831189155579
# Frame 40 - Class: 2.0, Conf: 0.2501685619354248
# Frame 40: 12 players detected
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 76.0ms
# Speed: 2.3ms preprocess, 76.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 41 - Class: 2.0, Conf: 0.9230709075927734
# Frame 41 - Class: 2.0, Conf: 0.919866144657135
# Frame 41 - Class: 2.0, Conf: 0.9115679264068604
# Frame 41 - Class: 2.0, Conf: 0.9110021591186523
# Frame 41 - Class: 2.0, Conf: 0.9081251621246338
# Frame 41 - Class: 2.0, Conf: 0.9062909483909607
# Frame 41 - Class: 2.0, Conf: 0.9053277969360352
# Frame 41 - Class: 2.0, Conf: 0.9041220545768738
# Frame 41 - Class: 2.0, Conf: 0.8593681454658508
# Frame 41 - Class: 1.0, Conf: 0.8398997783660889
# Frame 41 - Class: 3.0, Conf: 0.7678495645523071
# Frame 41 - Class: 0.0, Conf: 0.6703479290008545
# Frame 41 - Class: 2.0, Conf: 0.6569448113441467
# Frame 41 - Class: 2.0, Conf: 0.4655291438102722
# Frame 41 - Class: 2.0, Conf: 0.4043029844760895
# Frame 41: 15 players detected
#
# 0: 384x640 1 goalkeeper, 13 players, 1 referee, 74.4ms
# Speed: 2.6ms preprocess, 74.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 42 - Class: 2.0, Conf: 0.9132952690124512
# Frame 42 - Class: 2.0, Conf: 0.9131800532341003
# Frame 42 - Class: 2.0, Conf: 0.908595085144043
# Frame 42 - Class: 2.0, Conf: 0.9039100408554077
# Frame 42 - Class: 1.0, Conf: 0.8990938663482666
# Frame 42 - Class: 2.0, Conf: 0.8977510929107666
# Frame 42 - Class: 2.0, Conf: 0.894512414932251
# Frame 42 - Class: 2.0, Conf: 0.89042729139328
# Frame 42 - Class: 2.0, Conf: 0.8284463286399841
# Frame 42 - Class: 2.0, Conf: 0.8138075470924377
# Frame 42 - Class: 3.0, Conf: 0.8029097318649292
# Frame 42 - Class: 2.0, Conf: 0.7216481566429138
# Frame 42 - Class: 2.0, Conf: 0.43376830220222473
# Frame 42 - Class: 2.0, Conf: 0.26161065697669983
# Frame 42 - Class: 2.0, Conf: 0.2547309696674347
# Frame 42: 13 players detected
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 74.3ms
# Speed: 2.6ms preprocess, 74.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 43 - Class: 2.0, Conf: 0.9277916550636292
# Frame 43 - Class: 2.0, Conf: 0.9233831167221069
# Frame 43 - Class: 2.0, Conf: 0.9150012731552124
# Frame 43 - Class: 2.0, Conf: 0.9126265645027161
# Frame 43 - Class: 2.0, Conf: 0.9100843667984009
# Frame 43 - Class: 2.0, Conf: 0.8936174511909485
# Frame 43 - Class: 2.0, Conf: 0.8877745866775513
# Frame 43 - Class: 2.0, Conf: 0.8855205774307251
# Frame 43 - Class: 1.0, Conf: 0.8658697605133057
# Frame 43 - Class: 2.0, Conf: 0.8353167176246643
# Frame 43 - Class: 3.0, Conf: 0.8341891169548035
# Frame 43 - Class: 2.0, Conf: 0.7244857549667358
# Frame 43 - Class: 2.0, Conf: 0.48058196902275085
# Frame 43 - Class: 2.0, Conf: 0.3767305910587311
# Frame 43: 14 players detected
#
# 0: 384x640 1 goalkeeper, 14 players, 1 referee, 74.6ms
# Speed: 2.0ms preprocess, 74.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 44 - Class: 2.0, Conf: 0.9219980239868164
# Frame 44 - Class: 2.0, Conf: 0.9157212376594543
# Frame 44 - Class: 2.0, Conf: 0.9130614995956421
# Frame 44 - Class: 2.0, Conf: 0.9113801121711731
# Frame 44 - Class: 1.0, Conf: 0.9063239097595215
# Frame 44 - Class: 2.0, Conf: 0.8859076499938965
# Frame 44 - Class: 2.0, Conf: 0.8853124380111694
# Frame 44 - Class: 2.0, Conf: 0.8804703950881958
# Frame 44 - Class: 2.0, Conf: 0.8688307404518127
# Frame 44 - Class: 2.0, Conf: 0.7545760273933411
# Frame 44 - Class: 2.0, Conf: 0.7438293099403381
# Frame 44 - Class: 2.0, Conf: 0.647075891494751
# Frame 44 - Class: 3.0, Conf: 0.6340367794036865
# Frame 44 - Class: 2.0, Conf: 0.5878612995147705
# Frame 44 - Class: 2.0, Conf: 0.36214447021484375
# Frame 44 - Class: 2.0, Conf: 0.30295416712760925
# Frame 44: 16 players detected
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 83.4ms
# Speed: 2.5ms preprocess, 83.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 45 - Class: 2.0, Conf: 0.9162331223487854
# Frame 45 - Class: 2.0, Conf: 0.9147371649742126
# Frame 45 - Class: 2.0, Conf: 0.9130586981773376
# Frame 45 - Class: 2.0, Conf: 0.9029072523117065
# Frame 45 - Class: 2.0, Conf: 0.8911787867546082
# Frame 45 - Class: 2.0, Conf: 0.888376772403717
# Frame 45 - Class: 2.0, Conf: 0.8696488738059998
# Frame 45 - Class: 2.0, Conf: 0.8288549184799194
# Frame 45 - Class: 1.0, Conf: 0.8275737166404724
# Frame 45 - Class: 2.0, Conf: 0.7820630073547363
# Frame 45 - Class: 3.0, Conf: 0.7668509483337402
# Frame 45 - Class: 2.0, Conf: 0.6046547293663025
# Frame 45 - Class: 0.0, Conf: 0.42501336336135864
# Frame 45 - Class: 2.0, Conf: 0.3642365336418152
# Frame 45 - Class: 2.0, Conf: 0.2805120348930359
# Frame 45: 14 players detected
#
# 0: 384x640 1 goalkeeper, 12 players, 2 referees, 92.9ms
# Speed: 2.3ms preprocess, 92.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 46 - Class: 2.0, Conf: 0.919325590133667
# Frame 46 - Class: 2.0, Conf: 0.9182900190353394
# Frame 46 - Class: 2.0, Conf: 0.9146559834480286
# Frame 46 - Class: 2.0, Conf: 0.9141508936882019
# Frame 46 - Class: 2.0, Conf: 0.9036664962768555
# Frame 46 - Class: 1.0, Conf: 0.8948535919189453
# Frame 46 - Class: 2.0, Conf: 0.8774586915969849
# Frame 46 - Class: 2.0, Conf: 0.8143863081932068
# Frame 46 - Class: 2.0, Conf: 0.7894514203071594
# Frame 46 - Class: 2.0, Conf: 0.779095470905304
# Frame 46 - Class: 2.0, Conf: 0.7767348885536194
# Frame 46 - Class: 3.0, Conf: 0.7719269394874573
# Frame 46 - Class: 3.0, Conf: 0.47334912419319153
# Frame 46 - Class: 2.0, Conf: 0.2851344347000122
# Frame 46 - Class: 2.0, Conf: 0.25641655921936035
# Frame 46: 13 players detected
#
# 0: 384x640 1 goalkeeper, 8 players, 1 referee, 77.1ms
# Speed: 2.2ms preprocess, 77.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 47 - Class: 2.0, Conf: 0.9265681505203247
# Frame 47 - Class: 2.0, Conf: 0.9263020753860474
# Frame 47 - Class: 2.0, Conf: 0.9203892350196838
# Frame 47 - Class: 2.0, Conf: 0.9153082370758057
# Frame 47 - Class: 2.0, Conf: 0.9113450646400452
# Frame 47 - Class: 2.0, Conf: 0.8843449354171753
# Frame 47 - Class: 2.0, Conf: 0.8733803629875183
# Frame 47 - Class: 2.0, Conf: 0.8693304657936096
# Frame 47 - Class: 1.0, Conf: 0.856488823890686
# Frame 47 - Class: 3.0, Conf: 0.6902107000350952
# Frame 47: 10 players detected
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1 referee, 76.1ms
# Speed: 2.0ms preprocess, 76.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 48 - Class: 2.0, Conf: 0.9300524592399597
# Frame 48 - Class: 2.0, Conf: 0.9136616587638855
# Frame 48 - Class: 2.0, Conf: 0.9095063209533691
# Frame 48 - Class: 2.0, Conf: 0.8961865305900574
# Frame 48 - Class: 2.0, Conf: 0.8924999833106995
# Frame 48 - Class: 2.0, Conf: 0.8809927105903625
# Frame 48 - Class: 2.0, Conf: 0.8778173923492432
# Frame 48 - Class: 2.0, Conf: 0.8668828010559082
# Frame 48 - Class: 2.0, Conf: 0.7690936326980591
# Frame 48 - Class: 2.0, Conf: 0.7555549144744873
# Frame 48 - Class: 2.0, Conf: 0.581487238407135
# Frame 48 - Class: 3.0, Conf: 0.566497266292572
# Frame 48 - Class: 1.0, Conf: 0.49841880798339844
# Frame 48 - Class: 0.0, Conf: 0.32276296615600586
# Frame 48: 14 players detected
#
# 0: 384x640 1 goalkeeper, 11 players, 73.6ms
# Speed: 2.3ms preprocess, 73.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 49 - Class: 2.0, Conf: 0.9285807609558105
# Frame 49 - Class: 2.0, Conf: 0.9199849963188171
# Frame 49 - Class: 2.0, Conf: 0.9036768674850464
# Frame 49 - Class: 2.0, Conf: 0.9022318720817566
# Frame 49 - Class: 2.0, Conf: 0.8974253535270691
# Frame 49 - Class: 2.0, Conf: 0.8905003070831299
# Frame 49 - Class: 2.0, Conf: 0.8894268274307251
# Frame 49 - Class: 2.0, Conf: 0.8277366757392883
# Frame 49 - Class: 2.0, Conf: 0.7588012218475342
# Frame 49 - Class: 2.0, Conf: 0.7472715973854065
# Frame 49 - Class: 1.0, Conf: 0.3700990676879883
# Frame 49 - Class: 2.0, Conf: 0.32027730345726013
# Frame 49: 12 players detected
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 73.9ms
# Speed: 3.0ms preprocess, 73.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 50 - Class: 2.0, Conf: 0.9200537204742432
# Frame 50 - Class: 2.0, Conf: 0.9090009331703186
# Frame 50 - Class: 2.0, Conf: 0.9068186283111572
# Frame 50 - Class: 2.0, Conf: 0.9066168069839478
# Frame 50 - Class: 2.0, Conf: 0.8928817510604858
# Frame 50 - Class: 2.0, Conf: 0.8882233500480652
# Frame 50 - Class: 2.0, Conf: 0.8472923636436462
# Frame 50 - Class: 2.0, Conf: 0.8203373551368713
# Frame 50 - Class: 2.0, Conf: 0.8071354627609253
# Frame 50 - Class: 2.0, Conf: 0.7896345853805542
# Frame 50 - Class: 2.0, Conf: 0.6730508804321289
# Frame 50 - Class: 1.0, Conf: 0.6099945902824402
# Frame 50 - Class: 2.0, Conf: 0.3276197612285614
# Frame 50 - Class: 0.0, Conf: 0.3250119388103485
# Frame 50: 14 players detected
#
# 0: 384x640 2 goalkeepers, 12 players, 73.7ms
# Speed: 2.4ms preprocess, 73.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 51 - Class: 2.0, Conf: 0.9190682768821716
# Frame 51 - Class: 2.0, Conf: 0.90984046459198
# Frame 51 - Class: 2.0, Conf: 0.9029011130332947
# Frame 51 - Class: 2.0, Conf: 0.8956728577613831
# Frame 51 - Class: 2.0, Conf: 0.8917235732078552
# Frame 51 - Class: 2.0, Conf: 0.891249418258667
# Frame 51 - Class: 2.0, Conf: 0.8840328454971313
# Frame 51 - Class: 2.0, Conf: 0.8718504905700684
# Frame 51 - Class: 2.0, Conf: 0.8298628330230713
# Frame 51 - Class: 2.0, Conf: 0.8252158761024475
# Frame 51 - Class: 1.0, Conf: 0.5710333585739136
# Frame 51 - Class: 2.0, Conf: 0.4320032596588135
# Frame 51 - Class: 2.0, Conf: 0.3829198479652405
# Frame 51 - Class: 1.0, Conf: 0.28031691908836365
# Frame 51: 13 players detected
#
# 0: 384x640 11 players, 1 referee, 73.6ms
# Speed: 2.5ms preprocess, 73.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 52 - Class: 2.0, Conf: 0.9286991357803345
# Frame 52 - Class: 2.0, Conf: 0.9184220433235168
# Frame 52 - Class: 2.0, Conf: 0.9102957248687744
# Frame 52 - Class: 2.0, Conf: 0.8891318440437317
# Frame 52 - Class: 2.0, Conf: 0.8802168965339661
# Frame 52 - Class: 2.0, Conf: 0.8744491338729858
# Frame 52 - Class: 2.0, Conf: 0.8704681992530823
# Frame 52 - Class: 2.0, Conf: 0.8599972128868103
# Frame 52 - Class: 3.0, Conf: 0.8520879149436951
# Frame 52 - Class: 2.0, Conf: 0.8420175313949585
# Frame 52 - Class: 2.0, Conf: 0.8377648591995239
# Frame 52 - Class: 2.0, Conf: 0.6175045371055603
# Frame 52: 12 players detected
#
# 0: 384x640 12 players, 1 referee, 75.1ms
# Speed: 2.7ms preprocess, 75.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 53 - Class: 2.0, Conf: 0.9195738434791565
# Frame 53 - Class: 2.0, Conf: 0.9180654287338257
# Frame 53 - Class: 2.0, Conf: 0.9119533896446228
# Frame 53 - Class: 2.0, Conf: 0.886623203754425
# Frame 53 - Class: 2.0, Conf: 0.8769440054893494
# Frame 53 - Class: 2.0, Conf: 0.8732389211654663
# Frame 53 - Class: 2.0, Conf: 0.8561036586761475
# Frame 53 - Class: 3.0, Conf: 0.8551204204559326
# Frame 53 - Class: 2.0, Conf: 0.8483524322509766
# Frame 53 - Class: 2.0, Conf: 0.835097074508667
# Frame 53 - Class: 2.0, Conf: 0.8328968286514282
# Frame 53 - Class: 2.0, Conf: 0.5665139555931091
# Frame 53 - Class: 2.0, Conf: 0.33484864234924316
# Frame 53: 13 players detected
#
# 0: 384x640 1 goalkeeper, 9 players, 1 referee, 74.0ms
# Speed: 2.3ms preprocess, 74.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 54 - Class: 2.0, Conf: 0.9316291809082031
# Frame 54 - Class: 2.0, Conf: 0.9211698174476624
# Frame 54 - Class: 2.0, Conf: 0.9129077792167664
# Frame 54 - Class: 2.0, Conf: 0.9098090529441833
# Frame 54 - Class: 2.0, Conf: 0.9039880633354187
# Frame 54 - Class: 2.0, Conf: 0.9007928371429443
# Frame 54 - Class: 2.0, Conf: 0.8940982818603516
# Frame 54 - Class: 2.0, Conf: 0.8350721597671509
# Frame 54 - Class: 3.0, Conf: 0.8291983008384705
# Frame 54 - Class: 2.0, Conf: 0.8286164402961731
# Frame 54 - Class: 1.0, Conf: 0.5772035717964172
# Frame 54: 11 players detected
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 73.9ms
# Speed: 2.8ms preprocess, 73.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 55 - Class: 2.0, Conf: 0.9317916631698608
# Frame 55 - Class: 2.0, Conf: 0.9297969937324524
# Frame 55 - Class: 2.0, Conf: 0.921613872051239
# Frame 55 - Class: 2.0, Conf: 0.9055959582328796
# Frame 55 - Class: 2.0, Conf: 0.8962606191635132
# Frame 55 - Class: 2.0, Conf: 0.890178918838501
# Frame 55 - Class: 2.0, Conf: 0.8660078048706055
# Frame 55 - Class: 2.0, Conf: 0.8587101697921753
# Frame 55 - Class: 3.0, Conf: 0.8407770991325378
# Frame 55 - Class: 1.0, Conf: 0.8313323259353638
# Frame 55 - Class: 2.0, Conf: 0.7638105750083923
# Frame 55 - Class: 2.0, Conf: 0.7459143400192261
# Frame 55 - Class: 3.0, Conf: 0.5941025614738464
# Frame 55 - Class: 2.0, Conf: 0.44506093859672546
# Frame 55: 14 players detected
#
# 0: 384x640 1 goalkeeper, 12 players, 2 referees, 73.8ms
# Speed: 1.9ms preprocess, 73.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 56 - Class: 2.0, Conf: 0.93940669298172
# Frame 56 - Class: 2.0, Conf: 0.9248842597007751
# Frame 56 - Class: 2.0, Conf: 0.9246484637260437
# Frame 56 - Class: 2.0, Conf: 0.9240293502807617
# Frame 56 - Class: 2.0, Conf: 0.9191315770149231
# Frame 56 - Class: 2.0, Conf: 0.9030171632766724
# Frame 56 - Class: 2.0, Conf: 0.8936151266098022
# Frame 56 - Class: 2.0, Conf: 0.8812713027000427
# Frame 56 - Class: 3.0, Conf: 0.8096516728401184
# Frame 56 - Class: 2.0, Conf: 0.7824988961219788
# Frame 56 - Class: 3.0, Conf: 0.6944156289100647
# Frame 56 - Class: 2.0, Conf: 0.6908701658248901
# Frame 56 - Class: 2.0, Conf: 0.593738317489624
# Frame 56 - Class: 1.0, Conf: 0.31623461842536926
# Frame 56 - Class: 2.0, Conf: 0.2786889672279358
# Frame 56: 14 players detected
#
# 0: 384x640 11 players, 2 referees, 91.7ms
# Speed: 2.2ms preprocess, 91.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 57 - Class: 2.0, Conf: 0.9335110783576965
# Frame 57 - Class: 2.0, Conf: 0.9273738861083984
# Frame 57 - Class: 2.0, Conf: 0.9237688183784485
# Frame 57 - Class: 2.0, Conf: 0.9138074517250061
# Frame 57 - Class: 2.0, Conf: 0.909021258354187
# Frame 57 - Class: 2.0, Conf: 0.8944540023803711
# Frame 57 - Class: 2.0, Conf: 0.8935891389846802
# Frame 57 - Class: 2.0, Conf: 0.8726622462272644
# Frame 57 - Class: 2.0, Conf: 0.6779241561889648
# Frame 57 - Class: 3.0, Conf: 0.6676775813102722
# Frame 57 - Class: 2.0, Conf: 0.6347600221633911
# Frame 57 - Class: 2.0, Conf: 0.617005467414856
# Frame 57 - Class: 3.0, Conf: 0.46967989206314087
# Frame 57: 13 players detected
#
# 0: 384x640 11 players, 2 referees, 90.0ms
# Speed: 2.5ms preprocess, 90.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Frame 58 - Class: 2.0, Conf: 0.9314356446266174
# Frame 58 - Class: 2.0, Conf: 0.9287002682685852
# Frame 58 - Class: 2.0, Conf: 0.9246845841407776
# Frame 58 - Class: 2.0, Conf: 0.9200718402862549
# Frame 58 - Class: 2.0, Conf: 0.9109393358230591
# ...
#             1.1393,      2.1156,      1.7962,       -1.54,      1.2274,     -3.4691,    -0.16937,      -1.442,     -1.2794,   0.0093873,      1.2686,     -2.3056,     -0.6604,      0.7327,      -4.133,    -0.68313,    -0.66916,     -2.4135,     -3.5928,      -4.346,     0.99578,     -2.8458,     -2.9629,     -3.7073,
#            -2.9831,     -1.1146,     -2.8916,     -5.7786,     -2.1237,     -3.6253,     -3.3261,     -3.3487,     -1.2421,      2.7548,     0.67322,    -0.36444,    -0.25339,      1.4861,       2.749,      3.7494,      3.1092,      1.7643,      2.0141,     0.93039,     0.89882,       1.961,     -2.6636,      1.9275,
#            -1.5898,      2.2976,     0.78894,      1.7921,    -0.99615,     -2.4992,     -3.4793,     -4.1044,       -3.46,     -2.9825,     -1.6888,     0.69323,     0.78317,     0.33395,      1.5338,     -1.2405], dtype=float32)}, {'frame': 1, 'bbox': (np.float32(1792.5029), np.float32(80.318115), np.float32(27.599854), np.float32(51.47351)), 'features': array([      3.745,      3.9314,      1.6195,      1.0934,      1.6695,      3.5606,     0.23008,     -3.0117,     -3.1683,     -2.0552,      2.6336,      1.6593,      -0.418,     -2.1205,      0.9202,      -1.626,     0.30835,     -1.1478,    -0.75161,    -0.83326,      2.2313,     0.79204,    -0.29146,     -1.1233,
#             -2.255,     -2.6067,     0.26258,    -0.18969,     0.13496,      3.2621,      1.4877,      1.2965,      2.4766,      1.5139,      2.4288,     0.37609,      3.0009,     -3.1206,      1.1745,     -1.7824,      1.2226,    -0.75094,     0.24254,      2.0419,     -2.0774,     -1.7955,     -0.6862,      1.3147,
#           -0.21871,    0.018434,    -0.54106,      1.9708,      -1.141,    -0.67579,     -3.3753,    -0.50049,     -2.6882,     -2.3182,     0.88207,      4.3536,    -0.70629,     -2.1574,     0.81721,      1.2047,      1.6784,      1.3129,     0.11234,     -1.9399,     0.25665,     -4.3968,     -1.1817,     -3.4341,
#            0.18536,      2.5683,     -1.6935,     -2.0128,     -3.1634,     -2.5548,     0.81181,     -3.0943,      3.1698,     -1.6684,     -1.2216,    -0.15353,     -1.9608,     -1.3389,    -0.01464,      -1.063,     -0.7176,     -0.3088,       -1.25,    -0.21573,      0.6247,    -0.94438,      2.2229,      3.8567,
#             1.1644,      2.4409,      6.8119,      2.6837,       0.293,      2.3159,     -1.4419,      5.7471,     0.53563,    -0.55921,     -1.0445,     -2.0686,     -1.4384,     -1.8981,     -2.2869,     0.33519,     -2.1079,      1.7386,    -0.37439,     -2.5603,     -0.6154,      1.7602,      1.1936,    -0.17418,
#              2.171,     0.46628,    0.019447,     -1.1198,     -1.1225,    -0.46486,      2.8303,     -2.6293,      3.0406,      1.3027,    -0.42221,     0.31743,     0.77413,     0.70854,    -0.49102,      3.3045,      1.9964,      2.4982,     -1.9631,    -0.99416,    -0.36178,    -0.17793,      1.6374,     0.81037,
#           0.029303,      3.3957,      3.1932,      6.4604,      6.4297,      7.5112,      3.7777,     -1.4016,      2.9179,     0.28999,     -0.8252,      -1.358,     0.67487,     0.73582,       1.283,      1.0826,      1.6842,    -0.16728,     0.39453,     0.14225,      2.0531,      1.0009,       3.018,      4.0937,
#              2.378,     0.71635,     -0.9117,      1.1399,     0.12042,       1.641,     -1.2329,      2.5827,       1.278,   -0.076929,   -0.041946,     -0.5297,     0.42997,      3.6958,     -1.2307,      3.9464,       -1.49,     -1.6036,    -0.62248,     -1.0559,      2.3787,     0.65492,      2.2691,    -0.39729,
#             -1.657,     -0.9788,       1.983,    -0.80274,     -1.6756,     -1.4539,    -0.34669,     -1.0396,     0.90348,      -3.159,     -1.3457,     -2.2898,     -1.8648,      0.4935,      2.4194,      1.0858,      1.2565,      1.4395,      4.1102,      1.2664,     -0.1007,    -0.52686,    -0.69234,      1.0945,
#             1.3478,     -1.3675,     0.18746,     -1.3001,      3.2807,      3.1368,     0.29129,     0.44948,      1.1427,   -0.050732,    -0.79319,     0.33508,      2.5325,      1.0964,    -0.44818,    0.028063,      1.4419,     0.76547,      -1.707,      1.4736,     0.81541,    -0.66533,    -0.79713,    -0.37923,
#           -0.54076,      1.8306,     -1.3338,     0.21898,    -0.88941,    -0.27083,     0.09345,   -0.021694,      1.1113,      0.2386,     0.61762,   -0.047008,     0.91385,     0.24561,     -1.2855,    -0.28225,      1.6096,     0.48011,    0.099121,    -0.39951,     -1.0484,    -0.85509,    0.090943,     0.25169,
#             1.2642,     0.20948,      1.1428,      1.4051,     0.96273,     0.95498,      1.7505,      1.5508,      1.9364,      2.2998,      1.6321,     0.63231,    0.084933,      2.9636,      2.7962,     0.58726,      1.0127,    -0.54217,     0.68213,     0.32262,    -0.49321,    -0.91289,   -0.014029,     0.49882,
#            0.97884,    -0.50978,      1.5993,    -0.58155,    -0.01848,      1.7033,      4.3188,      2.7119,      4.0328,       2.291,    -0.01382,      0.2291,     -1.4683,    -0.13759,  -0.0043251,     0.10915,    -0.65873,     -3.3304,   -0.062717,    -0.11904,     -2.0757,     -0.2318,      2.2039,     -0.2245,
#            -1.6346,     -1.9379,     -1.3191,    -0.53308,     -1.2728,    -0.65877,    -0.57096,     0.76178,   -0.010287,     -1.5448,   -0.095706,    -0.94908,      1.4835,     0.07502,      1.4787,     -1.2629,     -2.5509,     -2.3661,      1.6253,       2.475,      1.0246,     -1.6197,    -0.30053,      2.7962,
#           0.031685,      2.8602,   -0.015447,      2.2349,    -0.13027,      2.2974,     0.12521,     -1.4583,       1.661,     0.92126,     -1.5269,      1.1069,     -2.8421,     -0.2906,    -0.71801,     0.87779,    -0.08272,      1.7432,     -1.3599,   -0.053781,      2.4563,      2.4082,      2.5864,      1.9575,
#              3.526,      2.0446,      1.5087,    -0.61273,      2.3811,     0.48585,     0.27993,       1.527,      2.1981,      2.3731,      1.6579,      2.9285,     0.69147,      1.1919,      2.8196,      2.9204,      2.6255,      2.8801,      1.6902,      1.5736,      2.5137,      1.5771,      1.3756,      1.9648,
#             3.1144,      2.1717,      1.7366,      3.5889,      2.5235,      2.3982,      3.5908,      1.6806,       5.979,     -1.7379,      3.5081,      3.5976,     -1.4838,     0.83868,     -2.3586,       1.901,    -0.71637,     -2.1729,     -2.2286,     0.84349,      4.6267,      1.6572,     -3.0451,      2.5195,
#             3.4097,    -0.88939,    -0.72959,     -2.3707,    -0.37289,     0.35615,     -4.0985,     -3.2197,      2.8037,    -0.37547,     0.17999,     0.46396,     -3.3717,     0.37896,     -1.0219,      1.0541,     0.52034,     -2.1074,    -0.53382,      1.6035,     0.20259,      0.9193,      -1.552,     -2.2359,
#            0.68118,      1.8426,     -3.1014,   -0.037675,    0.055054,     -1.1185,      5.0083,      0.7781,      -1.053,     0.80568,     -2.5815,     -4.0132,     0.18223,    -0.67111,      2.4506,       1.005,     -1.8473,       1.437,      2.4224,     0.41252,     -2.2504,     -2.2841,     -3.4001,     -1.5625,
#          -0.077004,     -2.6138,     -4.1489,     -1.6966,     -2.0916,       0.228,     0.14277,      1.9024,     -1.2734,      1.8057,      2.1527,     -2.8428,       1.091,     0.97794,    -0.23918,     -1.0355,      1.6028,       2.772,     -2.1505,     0.72599,     -1.7163,     -1.0378,     -1.5717,     0.48213,
#           -0.92007,      1.0691,      1.9303,    -0.41275,      1.7632,     -1.9439,     -1.5533,     -1.7951,     0.62657,     -1.6345,    -0.86865,     0.96115,     -2.5542,    -0.14441,     0.98992,     -2.6544,      -4.811,     -3.7177,     -3.8439,      2.9238,     -3.7777,  -0.0067063,      1.1202,       2.983,
#            0.92628,     0.28262,     -2.2371,      0.1737,      -2.786,     -3.7648,      3.5191,     0.49108,     0.71209,     -1.7072,    -0.48711,     0.16531,    -0.26639,     -2.2188,      2.4728,    -0.02978,     -3.4659,     0.98846,      2.7693,     -1.3881,    -0.69303,      1.5218,      -1.683,    -0.28695,
#            -1.9633,     -1.1758,    -0.20305,     0.26185,     -1.1319,     -2.6945,     0.31231,    -0.72901,    -0.19718,     -1.6946,     -1.6182,     -3.1093,      2.0451,    -0.76981,     -1.4729,    -0.70352,    -0.29521,     -1.1667,     -1.8219,      -2.027,    -0.45786,     -1.9793,      2.1591,   -0.023179,
#            -3.2666,     -1.9013,      1.4479,     -1.2321,     0.44514,     -1.3351,    -0.82002,   -0.063697,     0.41826,     0.15777,     0.09702,      -1.288,     -3.3373,     -2.4415,     -1.6834,      3.1035,     -4.1978,      1.0808,    0.055174,     -2.8373,      0.6976,      2.1094,      2.8867,       2.943,
#             1.1695,      1.0358,     -3.3767,     -1.8657,     -3.8366,     -1.4929,     -1.1058,    -0.20714,     0.33542,      1.2134,      1.0189,    -0.30698,     -2.0899,    -0.30629,     0.87273,     -2.4723,     -1.1819,     0.57203,     -2.1421,      0.4532,      1.6174,     -2.8747,     -1.2076,     -1.4119,
#            -0.7178,     -1.5649,      2.8128,     -1.6963,      4.0098,     -1.4919,      2.1441,     -4.0197,     -3.7966,     -1.5326,      0.3955,     -2.9653,     0.96945,    -0.47649,     -3.2985,      2.7602,    -0.75626,    -0.56878,      1.0311,     -1.4212,     0.35316,       1.703,     -2.1616,      2.3341,
#            -2.1995,     0.43438,    -0.25934,     0.88748,     -1.3669,     -1.0044,     0.84474,      2.5626,    -0.41886,      3.3589,     -1.9709,     0.85727,    -0.45797,     -2.5373,     -1.2153,     0.46757,     -6.1739,      1.2003,     -2.7699,     -3.9959,    -0.49264,     -1.2239,     0.93796,      3.3228,
#            -0.4942,      -1.287,     -2.5373,      1.4755,     -1.9845,      4.1054,      2.3052,      -3.048,      2.6433,    -0.21208,     -2.5348,      2.2789,      2.5649,    -0.58676,     0.37038,    -0.55013,     0.35432,       1.073,     0.85387,    0.076505,     -3.0143,     -2.0593,      1.3816,     0.29257,
#             2.3508,     -1.1588,      1.0026,      3.9345,      1.1415,    -0.18576,      3.5014,     -5.5172,      3.9229,     -2.0795,     -3.3378,     0.70554,      1.7115,     -1.6628,      2.9654,     -3.4211,     -1.7814,   -0.094393,     -1.2544,     0.17691,     0.77651,       3.057,      1.1425,    -0.18612,
#           -0.24888,     -2.9692,     -2.7227,     0.47336,     -1.2444,    -0.21035,      2.8358,    -0.87227,     -2.1621,      1.8555,     -0.9087,     -2.2641,    -0.15434,     -4.5844,     -2.4183,     -1.1191,      4.6807,   -0.047247,      2.3291,     0.50991,      -3.379,     0.12768,   -0.025891,      0.8107,
#            0.39559,     -3.1408,      3.1914,      1.0834,       1.304,     0.66085,      2.3719,       1.785,      1.3208,       0.744,     -1.5396,      1.4607,    -0.65636,     0.30172,     0.14877,     -3.5817,      2.3197,     -0.2349,     -1.1757,      3.2521,     0.50615,    -0.65813,     -1.7546,     0.46206,
#             1.5525,    -0.10408,      0.8233,      1.3816,     -3.4825,      1.2584,     -1.1944,      3.2172,      1.6315,     -1.3405,      -3.485,      -2.153,     0.32492,    -0.12986,      4.3189,     -1.3815,     -4.1421,     -2.0179,     -2.0889,      1.2595,     -2.5211,     -1.5489,      1.6576,     -1.5279,
#            -1.2739,     -2.1209,     -1.7037,     0.78697,      1.6304,     0.35744,     -2.1752,     -1.4216,     -1.3352,    -0.99693,     -1.6525,     -0.4778,    -0.21741,     0.28857,      3.0667,     0.27257,      -1.118,    -0.85912,      -2.045,      -2.287,     -2.2665,    -0.66229,    -0.42922,     -1.0055,
#           -0.69151,     -1.3797,     -2.8827,      1.2219,     -1.1944,     -1.2226,     0.35434,     -3.1069,     -2.3875,      0.5798,     0.24701,      1.0453,      2.5174,      2.5687,     -2.7456,   -0.085004,    -0.20649,    0.098983,     0.53507,    -0.73138,      2.6317,      2.2124,      6.1122,     -1.0132,
#             -2.836,      3.6303,      1.4759,     -2.7681,     -2.7554,      1.6703,      2.5866,     -1.5043,     -2.2648,     -1.0382,    0.014445,    -0.40994,      1.0704,    -0.46753,      1.3067,      1.7964,     -3.5961,      2.0875,      -1.202,     -2.2601,      2.2971,    -0.73552,      2.8831,     -2.4726,
#            -2.4129,      1.3363,      1.0059,     -2.5872,     -0.3643,    -0.89736,      1.1199,   -0.085246,     -1.9207,     -1.3148,     -2.6826,      0.6499,      2.7536,     -1.8638,     -1.2344,     0.85974,      1.5707,     -2.4115,     -4.6516,      0.6385,     0.37261,     -1.5062,      0.6746,      -3.303,
#             0.3648,     -1.1447,    0.089107,      2.9853,    -0.85265,     0.30229,     0.10475,      3.5105,    0.099326,     -2.9478,     -1.6558,     -1.2753,     -1.1433,     0.62917,     -0.4685,    -0.49857,   -0.088834,     0.22718,     -1.3367,     0.30656,     -3.5548,     0.76749,     -2.6521,     -2.3421,
#           -0.85325,     -3.8294,     0.56203,     0.46191,    -0.95531,     -1.6399,     -3.8546,      1.8718,    0.021029,     -1.8355,     -0.6567,       2.567,     -2.5385,      4.5241,      3.3623,     -2.5158,    -0.46569,     -1.4432,      2.1471,    0.072509,    -0.52706,     0.04641,     -1.2101,     -1.8453,
#              2.192,    -0.73389,      2.6184,     -1.2521,     -1.2972,    0.080948,     -2.3556,     -1.4679,    -0.77341,      1.5549,     -2.7174,     0.85607,     -1.7238,      3.1926,      1.7079,     0.81093,     -2.3253,     -2.0258,     -1.5738,      -1.071,     -1.0738,     -3.8492,     -2.6022,     -1.1576,
#            0.70592,      0.8434,     0.62435,    -0.30309,      1.1504,     -1.5906,     -0.7044,      0.5101,     0.49849,    -0.13133,      1.5299,     -1.8208,      1.1698,     0.61075,     -3.0284,     0.83385,      2.5006,     -1.4309,     -1.0944,    -0.42873,      1.1019,     -2.7196,     -2.2648,    -0.99324,
#           -0.86455,      -1.566,     -1.7857,     -5.4549,      -1.612,     -1.8944,    0.088679,     0.91162,     0.59639,      3.6972,      0.2644,     0.95028,    -0.19554,    -0.75662,     0.31504,      2.5991,         1.9,      1.7276,       1.153,     0.98657,    -0.35447,      2.5166,     -3.7861,     -1.1646,
#          0.0018857,      1.8517,      1.9421,     0.29626,     0.57108,     -1.6696,    -0.41365,     -2.6711,     -2.2682,     -1.3037,     -1.3776,     0.99141,      -0.187,     -0.2595,       0.996,     -2.7998], dtype=float32)}]]
# Matching players across videos...
# Number of tracked players: 35
# Saving player mapping to CSV...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 main()
#
# Cell In[14], line 14, in main()
#      12 print("Number of tracked players:", len(player_tracks))
#      13 print("Saving player mapping to CSV...")
# ---> 14 save_mapping(player_tracks)
#
# Cell In[13], line 12, in save_mapping(player_tracks, output_file)
#       3 for player_id, tracks in player_tracks.items():
#       4     for track in tracks:
#       5         data.append({
#       6             'player_id': player_id,
#       7             'frame': track['frame'],
#       8             'broadcast_x': track['broadcast_bbox'][0],
#       9             'broadcast_y': track['broadcast_bbox'][1],
#      10             'broadcast_w': track['broadcast_bbox'][2],
#      11             'broadcast_h': track['broadcast_bbox'][3],
# ---> 12             'tacticam_x': track['tacticam_bbox'][0],
#      13             'tacticam_y': track['tacticam_bbox'][1],
#      14             'tacticam_w': track['tacticam_bbox'][2],
#      15             'tacticam_h': track['tacticam_bbox'][3]
#      16         })
#      17 df = pd.DataFrame(data)
#      18 df.to_csv(output_file, index=False)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Process each frame (example for both feeds)
cap1 = cv2.VideoCapture('broadcast.mp4')
cap2 = cv2.VideoCapture('tacticam.mp4')

while True:
    ret1, frame1 = cap1.read()
    ret2, frame2 = cap2.read()
    if not ret1 or not ret2:
        break

    for cam_id, frame in enumerate([frame1, frame2]):
        results = model(frame)
        for r in results:
            boxes = r.boxes
            for box in boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                crop = frame[y1:y2, x1:x2]
                if crop.size == 0: continue

                # Feature extraction
                input_tensor = transform(crop).unsqueeze(0)
                with torch.no_grad():
                    feat = resnet(input_tensor).squeeze().numpy()

                # Match and assign global ID
                match_id = get_best_match(feat, global_id_bank)
                if match_id is None:
                    global_id_counter += 1
                    assign_id = global_id_counter
                    global_id_bank[assign_id] = [feat]
                else:
                    assign_id = match_id
                    global_id_bank[assign_id].append(feat)

                # Draw ID
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0,255,0), 2)
                cv2.putText(frame, f'ID: {assign_id}', (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0,255,0), 2)

    # Optional: show or save the frame
    # cv2.imshow("Frame1", frame1)
    # cv2.imshow("Frame2", frame2)
    # if cv2.waitKey(1) & 0xFF == ord('q'):
    #     break

cap1.release()
cap2.release()
cv2.destroyAllWindows()
